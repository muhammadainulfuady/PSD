# %% [markdown]
# # Mengunduh Data CH4 di Kabupaten Gresik
#
# Notebook ini mengambil data konsentrasi **CH4 (Metana)** dari Sentinel-5P melalui openEO, lalu menyimpannya sebagai file netCDF (`.nc`) dan CSV (`.csv`).

# %%
import openeo

# %%
connection = openeo.connect("openeo.dataspace.copernicus.eu").authenticate_oidc()
# Out:
# Authenticated using refresh token.

# %% [markdown]
# ## Area of Interest (AOI)
#
# Polygon lokasi pengamatan di Kabupaten Gresik. Format koordinat: `[longitude, latitude]`.

# %%
aoi = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "Polygon",
        "coordinates": [[
          [112.6193968, -7.1514786],
          [112.6600158, -7.1514786],
          [112.6600158, -7.1927923],
          [112.619805,  -7.1927923],
          [112.6193968, -7.1514786]
        ]]
      }
    }
  ]
}

# %% [markdown]
# ## Load Data CH4

# %%
s5 = connection.load_collection(
    "SENTINEL_5P_L2",
    temporal_extent=["2025-08-24", "2026-08-24"],
    spatial_extent={
        "west": 112.6193968,
        "south": -7.1927923,
        "east": 112.6600158,
        "north": -7.1514786,
    },
    bands=["CH4"],
)

# %%
# Rata-rata harian, lalu rata-rata di dalam polygon AOI
s5 = s5.aggregate_temporal_period(reducer="mean", period="day")
s5 = s5.aggregate_spatial(reducer="mean", geometries=aoi)

# %% [markdown]
# ## Jalankan Batch Job

# %%
job = s5.execute_batch(title="CH4 Gresik", outputfile="../data/nc/polutan_CH4_gresik.nc")
# Out:
# 0:00:00 Job 'j-26083112472442b38459a8d9809c56fc': send 'start'
# 0:00:04 Job 'j-26083112472442b38459a8d9809c56fc': queued (progress 0%)
# 0:00:09 Job 'j-26083112472442b38459a8d9809c56fc': queued (progress 0%)
# 0:00:16 Job 'j-26083112472442b38459a8d9809c56fc': queued (progress 0%)
# 0:00:24 Job 'j-26083112472442b38459a8d9809c56fc': queued (progress 0%)

# %% [markdown]
# ## Konversi netCDF ke CSV

# %%
import netCDF4
import pandas as pd

# Buka file NetCDF
ds = netCDF4.Dataset("../data/nc/polutan_CH4_gresik.nc")

# Ambil data CH4
ch4 = ds.variables["CH4"][0, :]

# Ambil waktu
time = ds.variables["t"][:]

# Ubah waktu menjadi tanggal
dates = netCDF4.num2date(
    time,
    units=ds.variables["t"].units
)

# Buat tanggal lengkap selama periode penelitian
full_dates = pd.date_range(
    start="2025-08-24",
    end="2026-08-24",
    freq="D"
)

# Pasangkan tanggal dengan nilai CH4
ch4_data = {
    date.strftime("%Y-%m-%d"): float(value)
    for date, value in zip(dates, ch4)
}

# Buat tabel dengan semua tanggal
df = pd.DataFrame({
    "date": full_dates.strftime("%Y-%m-%d")
})

# Masukkan nilai CH4 yang tersedia
df["CH4"] = df["date"].map(ch4_data)

# Simpan ke CSV
df.to_csv(
    "../data/csv/CH4_gresik_timeseries.csv",
    index=False
)

print("CSV berhasil disimpan")
print("Jumlah baris:", len(df))
# Out:
# CSV berhasil disimpan
# Jumlah baris: 366
